# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # UTSA CS 3793/5233: Assignment-2
#
# **Roberts - Clay - (gbi069)**

# %% [markdown]
# ## Learning Objectives
#
#
#
# *   Game Playing
# *   Chess - Board Setup & Rules
# *   Adversarial Search
# *   AI - Random vs MinMax

# %% [markdown]
# ## Description
#
# This assignment is focused on **game playing** and creating a proper **AI for chess**.
# In the following sections, you will complete a series of tasks to create a chess game board, rules for each chess piece, a Random AI and a MinMax AI that plays a game of chess for both players (white and black).
#
# The base structure of the code is provided. You are supposed to write code for each of the functions. Comments are provided on what should be done. You **CANNOT** use a complete chess library and change the base code structure completely. However, you **CAN** change the code layout and name/format of the functions.

# %% [markdown]
# #Chess Board Setup & Rules
#
# In this section, you will write code to import the necessary libraries and create:
#
# 1.   **ChessBoard** - This part will contain code to initialize the board, draw the board, get the board state and move piece.
# 2.   **ChessRules** - This part will contain code for the chess rules for each piece.

# %% [markdown]
# ##Import Libraries
#
# The code here will contain only **import** statements. A base list of the required libraries are already imported. You will most likely not need any other libraries, but if needed, add the import statements here. As mentioned before, you can not use any premade chess libraries.

# %%
# your code goes here
import string
import random
import os
import sys
import time
from IPython.display import clear_output

# %% [markdown]
# ##ChessBoard
#
# (10 points)
#
# Fill the code in the code structure provided below for the ChessBoard. The main use of this code block write functions to initialize the board, draw the board, get the board state and move piece. You can add any other functions if needed.

# %%
# you can add/change the input parameters for each function
# you can change the function names and also add more functions if needed


def ChessBoardSetup():
    # initialize and return a chess board - create a 2D 8x8 array that has the value for each cell
    # USE the following characters for the chess pieces - lower-case for BLACK and upper-case for WHITE
    # . for empty board cell
    # p/P for pawn
    # r/R for rook
    # t/T for knight
    # b/B for bishop
    # q/Q for queen
    # k/K for king
    board = [['r', 't', 'b', 'q', 'k', 'b', 't', 'r'],
             ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
             [ '.', '.', '.', '.', '.', '.', '.', '.'],
             [ '.', '.', '.', '.', '.', '.', '.', '.'],
             [ '.', '.', '.', '.', '.', '.', '.', '.'],
             [ '.', '.', '.', '.', '.', '.', '.', '.'],
             ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
             ['R', 'T', 'B', 'Q', 'K', 'B', 'T', 'R']]

    # use a dictionary to maintain coordinate positions
    across = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
    vert = ['8', '7', '6', '5', '4', '3', '2', '1']
    board_map = {}

    for i in range(len(vert)):
      for j in range(len(across)):
        curr = across[j] + vert[i]
        board_map[curr] = board[i][j]

    return board_map



def DrawBoard(board):
    # write code to print the board - following is one print example
    # r t b q k b t r
    # p p p p p p p p
    # . . . . . . . .
    # . . . . . . . .
    # . . . . . . . .
    # . . . . . . . .
    # P P P P P P P P
    # R T B Q K B T R

    across = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
    vert = ['8', '7', '6', '5', '4', '3', '2', '1']

    for i in range(len(vert)):
      for j in range(len(across)):
        curr = across[j] + vert[i]
        print(board[curr], end=' ')
      print()
    print()

def DrawMap():
    across = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
    vert = ['8', '7', '6', '5', '4', '3', '2', '1']

    for i in range(len(vert)):
      for j in range(len(across)):
        curr = across[j] + vert[i]
        print(curr, end=' ')
      print()
    print()

def MovePiece(board, from_piece, to_piece):
    # write code to move the one chess piece
    # you do not have to worry about the validity of the move - this will be done before calling this function
    # this function will at least take the move (from-piece and to-piece) as input and return the new board layout
    if board[to_piece] == '.':
      board[from_piece], board[to_piece] = board[to_piece], board[from_piece]
    else:
      board[to_piece] = board[from_piece]
      board[from_piece] = '.'

    if board[to_piece].lower() == 'p':
      if (to_piece[1] == '1'):
        board[to_piece] = 'q'
      elif (to_piece[1] == '8'):
        board[to_piece] = 'Q'


    return board


board = ChessBoardSetup()
DrawBoard(board)
DrawMap()
# Pieces from and to entered using coordinated of board map i.e. MovePiece('b2', 'b3', board)
# would move the pawn from b2 to b3
MovePiece(board, 'b2', 'b3')
DrawBoard(board)
MovePiece(board, 'e1', 'b3')
DrawBoard(board)
# tmp = 'a1'
# print(tmp[0], tmp[1])
# Out:
# r t b q k b t r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R T B Q K B T R
#
# a8 b8 c8 d8 e8 f8 g8 h8
# a7 b7 c7 d7 e7 f7 g7 h7
# a6 b6 c6 d6 e6 f6 g6 h6
# a5 b5 c5 d5 e5 f5 g5 h5
# a4 b4 c4 d4 e4 f4 g4 h4
# a3 b3 c3 d3 e3 f3 g3 h3
# a2 b2 c2 d2 e2 f2 g2 h2
# a1 b1 c1 d1 e1 f1 g1 h1
#
# r t b q k b t r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . P . . . . . .
# P . P P P P P P
# R T B Q K B T R
#
# r t b q k b t r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . . . .
# P . P P P P P P
# R T B Q . B T R

# %% [markdown]
# ##ChessRules
#
# (50 points)
#
# Fill the code in the code structure provided below for ChessRules. The main use of the code block is to write functions to design the rules for movement of each piece on the board. This block will also contain the function to check if the current player is in check, check-mate. You can also have functions that can return the current player's pieces that have legal moves in the current board state.
#
# Following are some **suggested** functions with the pseudocode provided. You can create/remove functions as needed.

# %%
# return True if the input move (from-square and to-square) is legal, else False
# this is the KEY function which contains the rules for each piece type
def IsMoveLegal(board, from_square, to_square):
    # input is from-square and to-square
    # use the input and the board to get the from-piece and to-piece
    if from_square not in board or to_square not in board:
      return False
    if from_square == to_square:
      return False

    black_p_start = ('a7', 'b7', 'c7', 'd7', 'e7', 'f7', 'g7', 'h7')
    white_p_start = ('a2', 'b2', 'c3', 'd4', 'e5', 'f6', 'g7', 'h8')

    ## PAWN
    if board[from_square].lower() == 'p':
      ## Check if piece is black and moving down
      if board[from_square] == 'p':
        if board[to_square] == '.':
          if ((int(from_square[1]) - int(to_square[1])) == 1) and (from_square[0] == to_square[0]):
            return True
          elif (from_square in black_p_start) and ((int(from_square[1]) - int(to_square[1])) == 2) and (from_square[0] == to_square[0]):
            if IsClearPath(board, from_square, to_square):
              return True
        elif ((int(from_square[1]) - int(to_square[1])) == 1) and (abs(ord(from_square[0]) - ord(to_square[0])) == 1) and (board[to_square].isupper()):
          return True
      ## Check if piece is white and moving up
      elif board[from_square] == 'P':
        if board[to_square] == '.':
          if ((int(from_square[1]) - int(to_square[1])) == -1) and (from_square[0] == to_square[0]):
            return True
          elif (from_square in white_p_start) and ((int(from_square[1]) - int(to_square[1])) == -2) and (from_square[0] == to_square[0]):
            if IsClearPath(board, from_square, to_square):
              return True
        elif ((int(from_square[1]) - int(to_square[1])) == -1) and (abs(ord(from_square[0]) - ord(to_square[0])) == 1) and (board[to_square].islower()):
          return True


    ## ROOK
    elif board[from_square].lower() == 'r':
      if board[from_square] == 'r':
        if (to_square[0] == from_square[0]) or (to_square[1] == from_square[1]):
          if (board[to_square] == '.' or board[to_square].isupper()):
            if IsClearPath(board, from_square, to_square):
              return True
      elif board[from_square] == 'R':
        if (to_square[0] == from_square[0]) or (to_square[1] == from_square[1]):
          if (board[to_square] == '.' or board[to_square].islower()):
            if IsClearPath(board, from_square, to_square):
              return True


    ## BISHOP
    elif board[from_square].lower() == 'b':
      diag = check_diag(from_square)
      if board[from_square] == 'b':
        if to_square in diag:
          if board[to_square] == '.' or board[to_square].isupper():
            if IsClearPath(board, from_square, to_square):
              return True
      elif board[from_square] == 'B':
        if to_square in diag:
          if board[to_square] == '.' or board[to_square].islower():
            if IsClearPath(board, from_square, to_square):
              return True


    ## QUEEN
    elif board[from_square].lower() == 'q':
      if board[from_square] == 'q':
        if (to_square[0] == from_square[0]) or (to_square[1] == from_square[1]):
            if (board[to_square] == '.' or board[to_square].isupper()):
              if IsClearPath(board, from_square, to_square):
                return True
        diag = check_diag(from_square)
        if to_square in diag:
          if board[to_square] == '.' or board[to_square].isupper():
            if IsClearPath(board, from_square, to_square):
              return True
      elif board[from_square] == 'Q':
        if (to_square[0] == from_square[0]) or (to_square[1] == from_square[1]):
            if (board[to_square] == '.' or board[to_square].islower()):
              if IsClearPath(board, from_square, to_square):
                return True
        diag = check_diag(from_square)
        if to_square in diag:
          if board[to_square] == '.' or board[to_square].islower():
            if IsClearPath(board, from_square, to_square):
              return True


    ## KNIGHT
    elif board[from_square].lower() == 't':
      col_diff = ord(to_square[0]) - ord(from_square[0])
      row_diff = ord(to_square[1]) - ord(from_square[1])
      if board[from_square] == 't':
        if board[to_square] == '.' or board[to_square].isupper():
          if col_diff == 1:
            if row_diff == -2:
              return True
            elif row_diff == 2:
              return True
          elif col_diff == 2:
            if row_diff == -1:
              return True
            elif row_diff == 1:
              return True
          elif col_diff == -1:
            if row_diff == -2:
              return True
            elif row_diff == 2:
              return True
          elif col_diff == -2:
            if row_diff == -1:
              return True
            elif row_diff == 1:
              return True
      elif board[from_square] == 'T':
        if board[to_square] == '.' or board[to_square].islower():
          if col_diff == 1:
            if row_diff == -2:
              return True
            elif row_diff == 2:
              return True
          elif col_diff == 2:
            if row_diff == -1:
              return True
            elif row_diff == 1:
              return True
          elif col_diff == -1:
            if row_diff == -2:
              return True
            elif row_diff == 2:
              return True
          elif col_diff == -2:
            if row_diff == -1:
              return True
            elif row_diff == 1:
              return True


    ## KING
    elif board[from_square].lower() == 'k':
      col_diff = abs(ord(to_square[0]) - ord(from_square[0]))
      row_diff = abs(int(to_square[1]) - int(from_square[1]))
      if board[from_square] == 'k':
        if board[to_square] == '.' or board[to_square].isupper():
          if col_diff == 1:
            if row_diff == 0 or row_diff == 1:
              return True
          elif col_diff == 0:
            if row_diff == 1:
              return True
      elif board[from_square] == 'K':
        if board[to_square] == '.' or board[to_square].islower():
          if col_diff == 1:
            if row_diff == 0 or row_diff == 1:
              return True
          elif col_diff == 0:
            if row_diff == 1:
              return True

    return False


# gets a list of legal moves for a given piece
# input = from-square
# output = list of to-square locations where the piece can move to
def GetListOfLegalMoves(board, from_square):
  moves = []
  across = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
  vert = ['8', '7', '6', '5', '4', '3', '2', '1']
  if board[from_square].isupper():
    color = 'white'
  elif board[from_square].islower():
    color = 'black'

  for i in range(len(vert)):
    for j in range(len(across)):
      curr = across[j] + vert[i]
      if (IsMoveLegal(board, from_square, curr)):
        if(DoesMovePutPlayerInCheck(board, color, from_square, curr) == False):
          moves.append(curr)

  return moves


# gets a list of all pieces for the current player that have legal moves
def GetPiecesWithLegalMoves(board, color):
  pieces = []
  across = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
  vert = ['8', '7', '6', '5', '4', '3', '2', '1']

  if color == 'black':
    for i in range(len(vert)):
      for j in range(len(across)):
        curr = across[j] + vert[i]
        if (board[curr].islower()):
          if (GetListOfLegalMoves(board, curr)):
            pieces.append(curr)

  elif color == 'white':
    for i in range(len(vert)):
      for j in range(len(across)):
        curr = across[j] + vert[i]
        if (board[curr].isupper()):
          if (GetListOfLegalMoves(board, curr)):
            pieces.append(curr)

  return pieces


loser = ''
# returns True if the current player is in checkmate, else False
def IsCheckmate(board, color):
  if (GetPiecesWithLegalMoves(board, color)):
    return False
  else:
    winner = color
    return True


# returns True if the given player is in Check state
def IsInCheck(board, color):

  across = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
  vert = ['8', '7', '6', '5', '4', '3', '2', '1']

  if (color == 'black'):
    king_loc = [king for king in board if board[king] == 'k']
    for i in range(len(vert)):
      for j in range(len(across)):
        curr = across[j] + vert[i]
        if (board[curr].isupper()):
          if (IsMoveLegal(board, curr, king_loc[0])):
            return True
          else:
            continue

  elif (color == 'white'):
    king_loc = [king for king in board if board[king] == 'K']
    for i in range(len(vert)):
      for j in range(len(across)):
        curr = across[j] + vert[i]
        if (board[curr].islower()):
          if (IsMoveLegal(board, curr, king_loc[0])):
            return True
          else:
            continue

  return False


# helper function to figure out if a move is legal for straight-line moves (rooks, bishops, queens, pawns)
# returns True if the path is clear for a move (from-square and to-square), non-inclusive
def IsClearPath(board, from_square, to_square):

    col_diff = abs(ord(to_square[0]) - ord(from_square[0]))
    row_diff = abs(ord(to_square[1]) - ord(from_square[1]))
    if col_diff == 1:
      if row_diff == 0 or 1:
        return True
    elif col_diff == 0:
      if row_diff == 1:
        return True
    else:
      if from_square[1] < to_square[1] < '9':
        from_square = from_square[0] + str(int(from_square[1]) + 1)
      elif from_square[1] > to_square[1] > '0':
        from_square = from_square[0] + str(int(from_square[1]) - 1)
      elif from_square[0] < to_square[0] < 'i':
        from_square = chr(ord(from_square[0]) + 1) + from_square[1]
      elif from_square[0] > to_square[0] >= 'a':
        from_square = chr(ord(from_square[0]) - 1) + from_square[1]
      elif from_square[1] > to_square[1] and from_square[0] < to_square[0]:
        from_square = chr(ord(from_square[0]) + 1) + str(int(from_square[1]) - 1)
      elif from_square[1] > to_square[1] and from_square[0] > to_square[0]:
        from_square = chr(ord(from_square[0]) - 1) + str(int(from_square[1]) - 1)
      elif from_square[1] < to_square[1] and from_square[0] < to_square[0]:
        from_square = chr(ord(from_square[0]) + 1) + str(int(from_square[1]) + 1)
      elif from_square[1] < to_square[1] and from_square[0] > to_square[0]:
        from_square = chr(ord(from_square[0]) - 1) + str(int(from_square[1]) + 1)

    if board[from_square] != '.':
      return False
    else:
      return IsClearPath(board, from_square, to_square)


# makes a hypothetical move (from-square and to-square)
# returns True if it puts current player into check
def DoesMovePutPlayerInCheck(board, color, from_square, to_square):

  tmp_board = board.copy()
  MovePiece(tmp_board, from_square, to_square)

  return(IsInCheck(tmp_board, color))


# returns a list of all diagnols
def check_diag(from_square):
    diag = []
    letter = from_square[0]
    num = from_square[1]
    while 'a' <= letter <= 'h' and '0' < num < '9':
      letter = chr(ord(letter) + 1)
      num = chr(ord(num) + 1)
      curr = letter + num
      diag.append(curr)

    letter = from_square[0]
    num = from_square[1]
    while 'a' <= letter <= 'h' and '0' < num < '9':
      letter = chr(ord(letter) + 1)
      num = chr(ord(num) - 1)
      curr = letter + num
      diag.append(curr)

    letter = from_square[0]
    num = from_square[1]
    while 'a' <= letter <= 'h' and '0' < num < '9':
      letter = chr(ord(letter) - 1)
      num = chr(ord(num) - 1)
      curr = letter + num
      diag.append(curr)

    letter = from_square[0]
    num = from_square[1]
    while 'a' <= letter <= 'h' and '0' < num < '9':
      letter = chr(ord(letter) - 1)
      num = chr(ord(num) + 1)
      curr = letter + num
      diag.append(curr)

    return diag

# %%
# my_dict = {'a1':'1', 'a2':'2'}
# print([king for king in my_dict if my_dict[king] == '2'])

# %% [markdown]
# #Artificial Intelligence
#
# In this section, you will write code for the Artificial Intelligence (AI) that will play a game of chess. You will write 2 types of AI:
#
# 1.   **RandomAI** - This part will contain code for moving a chess piece randomly.
# 2.   **MinMaxAI** - This part will contain code for moving a chess piece using the MinMax strategy discussed in the lecture.

# %% [markdown]
# ##RandomAI
#
# (10 points)
#
# Complete the function below that will perform a random move for the given player. The function will return the move (from-piece and to-piece). You will most likely not need to write any other function, but you can, if needed.

# %%
def GetRandomMove(board, color):

  check = GetPiecesWithLegalMoves(board, color)
  if (check != []):
    from_square = random.choice(check)
    to_square = random.choice(GetListOfLegalMoves(board, from_square))
    return (from_square, to_square)

  else:
    return ''

# %% [markdown]
# ##MinMaxAI
#
# (50 points)
#
# Complete the functions below that will perform a move for the given player using the MinMax AI strategy. One function will evaluate the board if a move is performed - give score for each of piece and calculate the score for the entire chess board. In the second function you will write actual code for the MinMax strategy and return the move (from-piece and to-piece). To get the allocated points, searching should be **2-ply (one Max and one Min)**. You will most likely not need to write any other function, but you can, if needed.
#
# ## Extra Credit
#
# *   **(5 points)** Modify the above MinMax strategy to be **4-ply (one Max, one Min, one Max, one Min)**.
# *   **(10 points)** Perform **alpha-beta pruning** for the MinMax strategy.

# %%
def evl(board):
  costs = {
      'p': 1,
      't': 3,
      'b': 3,
      'r': 5,
      'q': 9,
      'k': 100,

      'P': 1,
      'T': 3,
      'B': 3,
      'R': 5,
      'Q': 9,
      'K': 100
  }



  score = 0
  across = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
  vert = ['8', '7', '6', '5', '4', '3', '2', '1']

  for i in range(len(vert)):
    for j in range(len(across)):
      curr = across[j] + vert[i]
      if (board[curr].isupper()):
        score += costs[board[curr]]
      elif (board[curr].islower()):
        score -= costs[board[curr]]
      else:
        continue


  return score


def GetMinMaxMove(board, color):
    # return the best move for the current player using the MinMax strategy
    # to get the allocated points, searching should be 2-ply (one Max and one Min)

    # Following is the setup for a 2-ply game

    check = 0
    res = 0
    bestEnemyMove = ''
    bestMove = ''
    if color == 'black':
      enemy = 'white'
    else:
      enemy = 'black'

    pieces = GetPiecesWithLegalMoves(board, color)
    for piece in pieces:
      moves = GetListOfLegalMoves(board, piece)
      for move in moves:
        tmp_board = board.copy()
        MovePiece(tmp_board, piece, move)
        enemyPieces = GetPiecesWithLegalMoves(board, enemy)
        for enemyPiece in enemyPieces:
          enemyMoves = GetListOfLegalMoves(board, enemyPiece)
          for enemyMove in enemyMoves:
            tmp_board_2 = tmp_board.copy()
            MovePiece(tmp_board_2, enemyPiece, enemyMove)
            res = evl(tmp_board_2)
            if enemy == 'white' and res > check:
              check = res
              bestEnemyMove = (enemyPiece, enemyMove)
            elif enemy == 'black' and res < check:
              check = res
              bestEnemyMove = (enemyPiece, enemyMove)

        if color == 'black' and res < check:
          check = res
          bestMove = (piece, move)
        elif color == 'white' and res > check:
          check = res
          bestMove = (piece, move)

    if (bestMove != ''):
      return bestMove
    else:
      if IsCheckmate(board, color):
        return bestMove
      else:
        piece = random.choice(pieces)
        move = random.choice(GetListOfLegalMoves(board, piece))
        bestMove = (piece, move)
        return bestMove

    # OPTIONAL -- sometimes automated chess keeps on performing the moves again and again
    # e.g., move king left one square and then move king back - repeat
    # For this you will need to remember the previous move and see if the current best move is not the same and opposite as the previous move
    # If so, pick the second best move instead of the best move

# %%
#4ply
def GetMinMaxMove_4ply(board, color):
    # return the best move for the current player using the MinMax strategy
    # to get the allocated points, searching should be 2-ply (one Max and one Min)

    # Following is the setup for a 2-ply game

    check = 0
    res = 0
    bestEnemyMove = ''
    bestMove = ''

    if color == 'black':
      enemy = 'white'
    else:
      enemy = 'black'

    # Check next move
    pieces = GetPiecesWithLegalMoves(board, color)
    for piece in pieces:
      moves = GetListOfLegalMoves(board, piece)
      for move in moves:
        tmp_board = board.copy()
        MovePiece(tmp_board, piece, move)
        if (IsCheckmate(tmp_board, enemy)):
          return (piece, move)
        enemyPieces = GetPiecesWithLegalMoves(board, enemy)

        # Check enemies next move
        for enemyPiece in enemyPieces:
          enemyMoves = GetListOfLegalMoves(board, enemyPiece)
          for enemyMove in enemyMoves:
            tmp_board_2 = tmp_board.copy()
            MovePiece(tmp_board_2, enemyPiece, enemyMove)

            # Check second move
            if (not IsCheckmate(tmp_board_2, color)):
              sec_pieces = GetPiecesWithLegalMoves(tmp_board_2, color)
              for sec_piece in sec_pieces:
                sec_moves = GetListOfLegalMoves(tmp_board_2, sec_piece)
                for sec_move in sec_moves:
                  tmp_board_3 = tmp_board_2.copy()
                  MovePiece(tmp_board_3, sec_piece, sec_move)

                  # Check enemy second move
                  if (IsCheckmate(tmp_board, enemy)):
                    return (piece, move)
                  sec_enemyPieces = GetPiecesWithLegalMoves(tmp_board_3, enemy)
                  for sec_enemyPiece in sec_enemyPieces:
                    sec_enemyMoves = GetListOfLegalMoves(tmp_board_3, sec_enemyPiece)
                    for sec_enemyMove in sec_enemyMoves:
                      tmp_board_4 = tmp_board_3.copy()
                      MovePiece(tmp_board_4, sec_enemyPiece, sec_enemyMove)
                      res = evl(tmp_board_4)
                      if enemy == 'white' and res > check:
                        check = res
                        bestEnemyMove = (enemyPiece, enemyMove)
                      elif enemy == 'black' and res < check:
                        check = res
                        bestEnemyMove = (enemyPiece, enemyMove)
            else:
              res = evl(tmp_board_2)
              if enemy == 'white' and res > check:
                check = res
                bestEnemyMove = (enemyPiece, enemyMove)
              elif enemy == 'black' and res < check:
                check = res
                bestEnemyMove = (enemyPiece, enemyMove)
              continue

            if color == 'black' and res < check:
              check = res
              bestMove = (piece, move)
            elif color == 'white' and res > check:
              check = res
              bestMove = (piece, move)

    if (bestMove != ''):
      return bestMove
    else:
      if IsCheckmate(board, color):
        return bestMove
      else:
        piece = random.choice(pieces)
        move = random.choice(GetListOfLegalMoves(board, piece))
        bestMove = (piece, move)
        return bestMove

# %% [markdown]
# #Game Setup & Main Loop
#
# (05 points)
#
# Write code below to have a game-play between two AIs - Random vs MinMax. For each iteration, draw the board before and after a turn.

# %%
def CheckWin(check_cnt):
  if check_cnt == -1:
    print("STALEMATE")
  else:
    if check_cnt == 2:
      print("WHITE WINS")
    elif check_cnt == 1:
      print("BLACK WINS")
    else:
      print("NO MORE TURNS")

  print(turns)
  print()
  DrawBoard(board)

# %%
# initialize and setup the board
# player assignment and counter initializations
board = ChessBoardSetup()
turns = 1
N = 100
check_cnt = 0

# main game loop - while a player is not in checkmate or stalemate (<N turns)
# below is the rough looping strategy
moves = []
while not IsCheckmate(board, 'black') and not IsCheckmate(board, 'white') and turns < N:

    # White moves first
    rand_move = GetRandomMove(board, 'white')
    if (rand_move == '' and IsCheckmate(board, 'white')):
      check_cnt = 1
      continue
    elif (rand_move == ''):
      check_cnt = -1
      continue
    else:
      moves.append((board[rand_move[0]], rand_move[1]))
      MovePiece(board, rand_move[0], rand_move[1])

    # Black goes second
    if check_cnt != 0:
      continue
    else:
      min_move = GetMinMaxMove(board, 'black')
      if min_move == '' and rand_move == '':
        continue
      elif (min_move == '' and IsCheckmate(board, 'black')):
        check_cnt = 2
      elif min_move == '':
        check_cnt = -1
      else:
        moves.append((board[min_move[0]], min_move[1]))
        MovePiece(board, min_move[0], min_move[1])
    if (check_cnt != 0):
      break
    turns += 1

# check and print - Stalemate or Checkmate
CheckWin(check_cnt)
# Out:
# WHITE WINS
# 43
#
# r t b q k b t r
# . p . . . Q . .
# B . . . . . P .
# P . . K . . . .
# P . P . . . . .
# . . . . . . . p
# . . p B . . . P
# . R . . . . q .

# %% [markdown]
# #Submission Instructions
#
# 1.   Complete all tasks above - **File MUST contain the output for ALL cells**
# 2.   Export this notebook as .ipynb
#       (File > Download as ipynb)
# 3.   Upload the .ipynb file on Blackboard

# %% [markdown]
# ##Rubric
#
# *   (10 points) Chess Board Setup
# *   (50 points) Chess Rules Setup
# *   (10 points) Random AI
# *   (50 points) MinMax AI (2-ply)
# *   (05 points) Game Main Loop - Random vs MinMax
# *   (15 points) Extra Credit - 4-ply MinMax + alpha-beta pruning
